# %% [markdown]
# <h4>Obtaining Latitude and Longitude Values of Directory Locations</h4>

# %% [markdown]
# <h5>Import Dependencies</h5>

# %%
# !pip install w3lib
# !pip install selenium
# !pip install geocoder
# !pip install geopy
# !pip install folium

import numpy as np  # library to handle data in a vectorized manner
import pandas as pd  # library for data analsysis
import requests
import csv
import pprint as pp
import time
import re
import urllib.parse

from w3lib.url import url_query_parameter
from selenium import webdriver as wd
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import TimeoutException

# from selenium.common.exceptions import IndexError

from bs4 import BeautifulSoup as bs  # Beautiful Soup v4

# Only use when full dataframe needs to be viewed
# pd.set_option("display.max_rows", None, "display.max_columns", None)

import geocoder  # import geocoder

# module to convert an address into latitude and longitude values
from geopy.geocoders import Nominatim

# libraries for displaying images
from IPython.display import Image
from IPython.core.display import HTML

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

import folium  # plotting library

print('Libraries imported.')
# Out:
# Requirement already satisfied: w3lib in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (1.22.0)
# Requirement already satisfied: six>=1.4.1 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from w3lib) (1.15.0)
# Requirement already satisfied: selenium in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from selenium) (1.25.9)
# Requirement already satisfied: geocoder in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (1.38.1)
# Requirement already satisfied: future in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: requests in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from geocoder) (2.24.0)
# Requirement already satisfied: click in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from geocoder) (7.1.2)
# Requirement already satisfied: six in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from geocoder) (1.15.0)
# Requirement already satisfied: ratelim in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: idna<3,>=2.5 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from requests->geocoder) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from requests->geocoder) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from requests->geocoder) (1.25.9)
# Requirement already satisfied: decorator in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from ratelim->geocoder) (4.4.2)
# Requirement already satisfied: geopy in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (1.22.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from geopy) (1.50)
# Requirement already satisfied: folium in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (0.11.0)
# Requirement already satisfied: jinja2>=2.9 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from folium) (2.11.2)
# Requirement already satisfied: requests in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from folium) (2.24.0)
# Requirement already satisfied: numpy in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from folium) (1.19.0)
# Requirement already satisfied: branca>=0.3.0 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from folium) (0.4.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from requests->folium) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from requests->folium) (2020.6.20)
# Libraries imported.

# %% [markdown]
# <h5>Extract Contents of Excel File into DataFrame</h5>

# %%
akl_cbd_biz_extract = pd.read_excel("url_covid_classifier.xlsx")

akl_cbd_biz = akl_cbd_biz_extract.replace(np.nan, '', regex=True)

k = akl_cbd_biz.shape[0]

akl_cbd_biz.head()
# Out:
#            Name Main Category              Sub Category 1 Sub Category 2  \
# 0      100 Fix         Retail  Electronics and technology
# 1  109 Doctors       Services        Health and wellbeing        Doctors
# 2       16 Tun    Hospitality              Bars and clubs    Restaurants
# 3   1Above Ltd       Services        Health and wellbeing
# 4    2 Degrees         Retail  Electronics and technology
#
#               Address Line 1           Address Line 2  \
# 0                                19  Shortland Street
# 1                    Level 9         109 Queen Street
# 2                               10/26 Jellicoe Street
# 3  Old Sofrana House Level 1   18-Customs Street East
# 4               Civic Centre  8 Wellesley Street West
#
#                         Precinct Post Code  Locality         Phone  \
# 0     \n\nFederal & Elliott \n\n      1010  Auckland
# 1          \n\nQueen Street \n\n            Auckland  (09)3660109
# 2  \n\nViaduct & Waterfront \n\n            Auckland   09 368 7712
# 3  \n\nViaduct & Waterfront \n\n            Auckland   09 379 5708
# 4     \n\nFederal & Elliott \n\n            Auckland   09 366 1584
#
#                     Web URL     Web URL COVID Info
# 0                                           No URL
# 1                                           No URL
# 2             www.16tun.com        URL Parse Error
# 3         www.fly1above.com  No Obvious COVID Info
# 4  www.2degreesmobile.co.nz  No Obvious COVID Info

# %% [markdown]
# <h5>Set Up and Run Latitude and Longitude Information Loop</h5>

# %%
address_l = []
latitude_l = []
longitude_l = []

c = 0
for c in range(0, k):
    # extract street address from DataFrame
    addy = akl_cbd_biz['Address Line 2'][c]
    
    # Perform data cleaning
    substr = addy.split()     # Get individual words 
    string = " ".join(sorted(set(substr), key=substr.index))    # Remove repeated words and multi-spaces
    if string[0].isdigit():            
        addy = string
    else:
        addy = re.split(r'(^[^\d]+)', string)[1:][1]   # Remove leading text found in string
        
    # Perform other desired data cleaning steps e.g. remove dashes
    
    address = addy + ', Auckland 1010'                 # Add City and Postcode
      
    # Obtain Latitude and Longitude Values
    try:
        geolocator = Nominatim(user_agent="foursquare_agent")
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude

    except:
        latitude = 'error'
        longitude = 'error'

    address_l.append(address)
    latitude_l.append(latitude)
    longitude_l.append(longitude)
    
    # Monitor Progress
    print(address)
    print(latitude, longitude)
    print(c)

# %% [markdown]
# <h5>Create New DataFrame, Populate and View</h5>

# %%
data = {'Look-up Address': address_l,
        'Latitude': latitude_l,
        'Longitude': longitude_l
        }

temp = pd.DataFrame(data)
temp.head()
# Out:
#                           Look-up Address Latitude Longitude
# 0      19 Shortland Street, Auckland 1010 -36.8468   174.767
# 1         109 Queen Street, Auckland 1010 -36.8546   174.763
# 2    10/26 Jellicoe Street, Auckland 1010 -36.9544   174.843
# 3   18-Customs Street East, Auckland 1010 -36.8447   174.767
# 4  8 Wellesley Street West, Auckland 1010 -36.8509   174.764

# %% [markdown]
# <h5>Append New DataFrame to Existing DataFrame, View and Save to Excel File</h5>

# %%
akl_cbd_biz = pd.concat([akl_cbd_biz, temp], axis=1)

akl_cbd_biz['Precinct'] = akl_cbd_biz['Precinct'].str.strip()    # Remove line breaks

akl_cbd_biz.to_excel(
    r'FULL FILE PATH\FILE.xlsx', index=False, header=True)  # Saved as "address_to_lat_lon.xlsx"

print("Saved to excel file")

akl_cbd_biz.head()
# Out:
# Saved to excel file
#            Name Main Category              Sub Category 1 Sub Category 2  \
# 0      100 Fix         Retail  Electronics and technology
# 1  109 Doctors       Services        Health and wellbeing        Doctors
# 2       16 Tun    Hospitality              Bars and clubs    Restaurants
# 3   1Above Ltd       Services        Health and wellbeing
# 4    2 Degrees         Retail  Electronics and technology
#
#               Address Line 1           Address Line 2              Precinct  \
# 0                                19  Shortland Street     Federal & Elliott
# 1                    Level 9         109 Queen Street          Queen Street
# 2                               10/26 Jellicoe Street  Viaduct & Waterfront
# 3  Old Sofrana House Level 1   18-Customs Street East  Viaduct & Waterfront
# 4               Civic Centre  8 Wellesley Street West     Federal & Elliott
#
#   Post Code  Locality         Phone                   Web URL  \
# 0      1010  Auckland
# 1            Auckland  (09)3660109
# 2            Auckland   09 368 7712             www.16tun.com
# 3            Auckland   09 379 5708         www.fly1above.com
# 4            Auckland   09 366 1584  www.2degreesmobile.co.nz
#
#       Web URL COVID Info                         Look-up Address Latitude  \
# 0                 No URL      19 Shortland Street, Auckland 1010 -36.8468
# 1                 No URL         109 Queen Street, Auckland 1010 -36.8546
# 2        URL Parse Error    10/26 Jellicoe Street, Auckland 1010 -36.9544
# 3  No Obvious COVID Info   18-Customs Street East, Auckland 1010 -36.8447
# 4  No Obvious COVID Info  8 Wellesley Street West, Auckland 1010 -36.8509
#
#   Longitude
# 0   174.767
# 1   174.763
# 2   174.843
# 3   174.767
# 4   174.764
